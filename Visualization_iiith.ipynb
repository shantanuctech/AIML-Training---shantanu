# %% [markdown]
# <a href="https://colab.research.google.com/github/shantanuctech/AIML-Training---shantanu/blob/main/Visualization_iiith.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
x=np.random.random(100)
y=np.random.normal(size=100)

# %% [markdown]
# ### Distribution of Data

# %%
plt.hist(x,bins=20);

# %%
plt.hist(x,bins=20,color='red')
# Out:
# (array([6., 9., 4., 7., 8., 1., 6., 4., 5., 3., 5., 5., 3., 1., 6., 8., 4.,
#         5., 4., 6.]),
#  array([0.01416803, 0.06285878, 0.11154952, 0.16024026, 0.20893101,
#         0.25762175, 0.30631249, 0.35500324, 0.40369398, 0.45238472,
#         0.50107547, 0.54976621, 0.59845696, 0.6471477 , 0.69583844,
#         0.74452919, 0.79321993, 0.84191067, 0.89060142, 0.93929216,
#         0.9879829 ]),
#  <BarContainer object of 20 artists>)

# %%
sns.histplot(y,bins=20,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(x,bins=20,kde=True);

# %%
sns.kdeplot(y,color='magenta',fill=True);

# %%
sns.kdeplot(x,color='red', fill='True')
sns.kdeplot(x,color='red', fill='True')

# %%
plt.subplot(1,2,1)
sns.kdeplot(x,color='magenta', fill='True')
plt.subplot(1,2,2)
sns.kdeplot(y,color='magenta', fill='True')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.subplot(2,1,1)
sns.kdeplot(x,color='magenta', fill='True')
plt.subplot(2,1,2)
sns.kdeplot(y,color='blue', fill='True')

# %%
tips_df=sns.load_dataset('tips')
print(tips_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
print(tips_df.head(10))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
print(tips_df.sample(10))
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 223       15.98  3.00  Female     No  Fri   Lunch     3
# 153       24.55  2.00    Male     No  Sun  Dinner     4
# 16        10.33  1.67  Female     No  Sun  Dinner     3
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 115       17.31  3.50  Female     No  Sun  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 38        18.69  2.31    Male     No  Sat  Dinner     3

# %%
tips_df.day.unique()
#tips_df['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips_df['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
sns.histplot(tips_df.total_bill,color='blue',bins=20);

# %%
sns.histplot(tips_df.tip,color='blue',bins=20);

# %%
sns.histplot(tips_df.tip/tips_df.total_bill,color='blue',bins=20);

# %%
tips_df[tips_df.tip/tips_df.total_bill>0.5]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 172        7.25  5.15  Male    Yes  Sun  Dinner     2

# %%
tips_df[tips_df.tip/tips_df.total_bill>0.4]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2

# %%
print(tips_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
days=tips_df.day.unique()
print(days)
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips_df[tips_df['day']=='Sun'].count()
# Out:
# total_bill    76
# tip           76
# sex           76
# smoker        76
# day           76
# time          76
# size          76
# dtype: int64

# %%
tips_df[tips_df['day']=='Sun']['day'].count()
# Out:
# 76

# %%
days=tips_df.day.unique()
day_data={}
for each_day in days:
  day_data[each_day]=[tips_df[tips_df['day']==each_day]['day'].count()]
  print(day_data)
# Out:
# {'Sun': [76]}
# {'Sun': [76], 'Sat': [87]}
# {'Sun': [76], 'Sat': [87], 'Thur': [62]}
# {'Sun': [76], 'Sat': [87], 'Thur': [62], 'Fri': [19]}

# %%
day_df=pd.DataFrame(day_data)
sns.barplot(day_df);

# %%
tips_df.groupby('day')['day'].count()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: day, dtype: int64

# %%
tips_series=tips_df.groupby('day')['day'].count()
sns.barplot(x=tips_series.index,y=tips_series.values)
# Out:
# <Axes: xlabel='day'>

# %%
tips_series=tips_df.groupby('day')['day'].count()
sns.barplot(x=tips_series.index,y=tips_series.values)
# Out:
# <Axes: xlabel='day'>

# %% [markdown]
# ### Relational Plots

# %%
sns.relplot(data=tips_df,x='total_bill',y='tip')

# %%
sns.regplot(data=tips_df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip');

# %%
sns.lmplot(data=tips_df[tips_df.sex=='Male'],x='total_bill',y='tip');

# %%
sns.lmplot(data=tips_df[tips_df.sex=='Female'],x='total_bill',y='tip');

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip',hue='sex');

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip',hue='day');

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip',hue='day',col='smoker');

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip',hue='day',col='smoker',row='sex');

# %%
sns.pairplot(tips_df) #numerical col only

# %% [markdown]
# ##Composition of Data

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%');

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%',shadow='true');

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%',shadow='true',explode=[0,1,0,0]);

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%',shadow='true',wedgeprops=dict(width=0.25));

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%',shadow='true',wedgeprops=dict(width=0.25),explode=[0,1,0,0]);
