# %% [markdown]
# <a href="https://colab.research.google.com/github/shantanuctech/AIML-Training---shantanu/blob/main/PSU_Day_06_Object_Detection_FasterRCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Object Detection
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# <hr/>
# Object detection is a computer vision and image processing related technique that deals with detecting instances of semantic objects in an image or video. Unlike image classification where labeling object is sufficient object detection involves identifying the position and the boundaries of an object, and only then classifying it into the corresponding categories.

# %% [markdown]
# <hr/>
# <b>Dataset:</b> In this project we are dealing with fruit images dataset. The dataset include the pictures of fruits as well as the `.xml` files that among other things describe the ground truth bounding box coordinates around the objects.
# <br/>
# <b>The main question of the project is:</b> Given the training images with ground truth bounding boxes can we detect fruits in unseen images?
#
# <b>Methods and Findings:</b> We are leveraging an object detection model known as Faster R-CNN to detect our fruits. In order to be able to utilize the model we are creating a dataset class to capture the images and preprocess them. The results are fed into the model.
#
# 1. Create a dataset class to read and preprocess the data.
#
# 2. Define our model with corresponding attributes.
#
# 3. Track the model's performance.

# %%
# !pip install -q torch_snippets lovely-tensors torchinfo

from torch_snippets import *
from IPython import display
import matplotlib.pyplot as plt
import matplotlib.patches as patches
display.set_matplotlib_formats('svg')

from torchinfo import summary

import torch
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import models
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from xml.etree import ElementTree as et
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 33.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 34.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.9/172.9 kB 17.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 28.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 21.8 MB/s eta 0:00:00
#   Building wheel for typing (setup.py) ... done
# <ipython-input-1-1daa5d9ef347>:7: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   display.set_matplotlib_formats('svg')

# %%
# !rm -r dataset/
# Out:
# rm: cannot remove 'dataset/': No such file or directory

# %%
# unzip the dataset
# !mkdir dataset
# !unzip -q test_zip.zip -d ./dataset

# %%
# !unzip -q train_zip.zip -d ./dataset

# %%
#!zip -r fruit_dataset.zip dataset

# %% [markdown]
# # Reading the Data 📖

# %% [markdown]
# The data is not big. It contains $240$ images of fruits in the train folder and $60$ images in the test folder.
# At this part of the project we will:
# - retrieve the images
# - resize them
# - retrieve the objects labels for each image
# - retrieve the ground truth bounding boxes of the objects for each image
# - resize them accordingly

# %%
root = '/content/train.zip/'

# we have four labels
labels = ['background', 'orange', 'apple', 'banana']
label2targets = {l: t for t, l in enumerate(labels)}
targets2label = {t: l for l, t in label2targets.items()}
num_classes = len(targets2label)

# %%
def plot_img_bbox(img, target):
    fig, a = plt.subplots(1,1)
    fig.set_size_inches(5,5)
    a.imshow(img)
    for box in target:
        x, y, width, height  = box[0], box[1], box[2]-box[0], box[3]-box[1]
        rect = patches.Rectangle((x, y),
                                 width, height,
                                 linewidth = 2,
                                 edgecolor = 'r',
                                 facecolor = 'none')

        a.add_patch(rect)
    plt.show()

# %%
def preprocess_img(img):
    img = torch.tensor(img).permute(2, 0 ,1)
    return img.float()

class FruitsDataset(Dataset):
    def __init__(self, root=root, transforms=None):
        self.root = root
        self.transforms = transforms
        self.img_paths = sorted(Glob(self.root + '/*.jpg'))
        self.xlm_paths = sorted(Glob(self.root + '/*.xml'))

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        w, h = 224, 224
        img_path = self.img_paths[idx]
        xlm_path = self.xlm_paths[idx]
        img = Image.open(img_path).convert('RGB')
        W, H = img.size
        img = np.array(img.resize((w, h),
                       resample=Image.Resampling.BILINEAR))/255.
        xlm = et.parse(xlm_path)
        objects = xlm.findall('object')
        labels = []
        boxes = []
        for obj in objects:
            label = obj.find('name').text
            labels.append(label)
            XMin = float(obj.find('bndbox').find('xmin').text)
            YMin = float(obj.find('bndbox').find('ymin').text)
            XMax = float(obj.find('bndbox').find('xmax').text)
            YMax = float(obj.find('bndbox').find('ymax').text)
            bbox = [XMin / W, YMin / H, XMax / W, YMax / H]
            bbox = (bbox * np.array([w, h, w, h])).astype(np.int16).tolist()
            boxes.append(bbox)
        target = {}
        target['labels'] = torch.tensor([label2targets[label] for label in labels]).long()
        target['boxes'] = torch.tensor(boxes).float()
        img = preprocess_img(img)
        return img, target

    def collate_fn(self, batch):
        return tuple(zip(*batch))

val_root = '/content/dataset/test/'

train_ds = FruitsDataset(val_root)
train_dl = DataLoader(train_ds, batch_size=4, shuffle=True, collate_fn=train_ds.collate_fn)

val_ds = FruitsDataset(root=val_root)
val_dl = DataLoader(val_ds, batch_size=2, shuffle=True, collate_fn=val_ds.collate_fn)

img, target = train_ds[10]
plot_img_bbox(img.permute(1,2,0), target['boxes'])

# %% [markdown]
# # Model evaluation 🤖

# %% [markdown]
# Let's try to understand the core phases of the prediction process our model is using:
# 1. Anchor Boxes:
# These serve as a replacement of the selective search based region proposals.
# - <b>Key Idea</b> Typically the majority of the objects have a similar shape e.g. a ground truth bounding box for a person will have a greater height than width.
#  - The inspection of the ground truth bounding boxes of the objects present in the images helps to build a descent idea about the height and the width of the objects.
#  - Albeit, some images can be scaled. This will result in the the distortion of the object's height and width. Hence, an aspect ration $\frac{\text{height}}{\text{width}}$ is computed from the ground truth values for objects of each class.
#  - After completion of the previous two steps we can define the <span style="background-color: green;">anchor boxes</span> with heights and widths representing the majority of objects' bounding boxes within certain class for our dataset.
#
# At this stage we have the anchor boxes of certain height/width for each class of objects. However, how one can use such boxes to detect the objects of those classes in the images?
# The answer is by sliding:
# - Slide each anchor box over an image from top left to bottom right.
#
# 2. Region Proposal Network (RPN)
# We pass the image's crops identified by anchor boxes to the RPN model. It then suggests the likelihood of the crop containing an object.
# - For each possible crop compute the IoU$^*$. Those boxes that have higher IoU then some threshold will get a label that mentions that they contain an object. Others will be labeled $0$.
# All the candidate crops that have small IoU will be discarded while training.
#
# Finally, we can perform non-max supression (since multiple crops can contain the same object) to identify the region candidate that has the highest probability of containing an object and eliminate other region candidates that have a high overlap with it.
#
# At this point we managed to build up bounding boxes that are likely to contain the objects. Are we done? Not yet. We should also predict what kind the class of the object around which the bounding box has been created.
#
# 3. Classification and Regression
# Here we are using something known as RoI pooling layer and pass both the image featured learned from the CNN as well as the candidate bounding boxes to RoI.
# RoI pooling is needed to convert each feature map into a fixed dimension map that onward would be passed to fully connected network (FCN). The conversion goes like this:
#  3.1. Take the feature map and the candidate bounding box (i.e. region proposal).
#  3.2. Divide the candidate bounding box into equal-sized sections. The number of this sections is the same as the dimension of the output.
#  3.3 Do max-pooling for these sections.
#
# So, RoI lets us to form feature maps of fixed size from a list of candidate bounding boxes of different size.
# The remaining is straightforward:
# - Flatten the RoI outputs pass to FCN that predicts:
#
# a) The class of the object.
#
# b) The amount of offset for the candidate bounding box to maximize the IoU with the ground truth.
#
# $^*$Remark: Intersection over Union (IoU) is a measure of accuracy i.e. how overlapping the predicted and actual bounding boxes are
# $$ IoU = \frac{\text{Area of overlapping region}}{\text{Area of combined region}} $$

# %% [markdown]
# <hr/>
# All of this is done behind the scenes. Here we are not going to train the model from scratch and go through all those phases (partly because we don't possess the computational resources to do so). Hence, we will use an already pretrained mode from pytorch library.

# %%
def get_model():
    model = models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    #print(in_features)
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    return model

# test the model
imgs, targets = next(iter(train_dl))
imgs = list(img.to(device) for img in imgs)
targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

model = get_model().to(device)
print(model(imgs, targets))
summary(model, (1,3,224,224))
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:00<00:00, 228MB/s]
# {
#     'loss_classifier': tensor grad NllLossBackward0 cuda:0 1.220,
#     'loss_box_reg': tensor grad DivBackward0 cuda:0 0.253,
#     'loss_objectness': tensor grad BinaryCrossEntropyWithLogitsBackward0 cuda:0 0.002,
#     'loss_rpn_box_reg': tensor grad DivBackward0 cuda:0 0.004
# }
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# FasterRCNN                                              [100, 4]                  --
# ├─GeneralizedRCNNTransform: 1-1                         [1, 3, 800, 800]          --
# ├─BackboneWithFPN: 1-2                                  [1, 256, 13, 13]          --
# │    └─IntermediateLayerGetter: 2-1                     [1, 2048, 25, 25]         --
# │    │    └─Conv2d: 3-1                                 [1, 64, 400, 400]         (9,408)
# │    │    └─FrozenBatchNorm2d: 3-2                      [1, 64, 400, 400]         --
# │    │    └─ReLU: 3-3                                   [1, 64, 400, 400]         --
# │    │    └─MaxPool2d: 3-4                              [1, 64, 200, 200]         --
# │    │    └─Sequential: 3-5                             [1, 256, 200, 200]        (212,992)
# │    │    └─Sequential: 3-6                             [1, 512, 100, 100]        1,212,416
# │    │    └─Sequential: 3-7                             [1, 1024, 50, 50]         7,077,888
# │    │    └─Sequential: 3-8                             [1, 2048, 25, 25]         14,942,208
# │    └─FeaturePyramidNetwork: 2-2                       [1, 256, 13, 13]          --
# │    │    └─ModuleList: 3-15                            --                        (recursive)
# │    │    └─ModuleList: 3-16                            --                        (recursive)
# │    │    └─ModuleList: 3-15                            --                        (recursive)
# │    │    └─ModuleList: 3-16                            --                        (recursive)
# │    │    └─ModuleList: 3-15                            --                        (recursive)
# │    │    └─ModuleList: 3-16                            --                        (recursive)
# │    │    └─ModuleList: 3-15                            --                        (recursive)
# │    │    └─ModuleList: 3-16                            --                        (recursive)
# │    │    └─LastLevelMaxPool: 3-17                      [1, 256, 200, 200]        --
# ├─RegionProposalNetwork: 1-3                            [1000, 4]                 --
# │    └─RPNHead: 2-3                                     [1, 3, 200, 200]          --
# │    │    └─Sequential: 3-18                            [1, 256, 200, 200]        590,080
# │    │    └─Conv2d: 3-19                                [1, 3, 200, 200]          771
# │    │    └─Conv2d: 3-20                                [1, 12, 200, 200]         3,084
# │    │    └─Sequential: 3-21                            [1, 256, 100, 100]        (recursive)
# │    │    └─Conv2d: 3-22                                [1, 3, 100, 100]          (recursive)
# │    │    └─Conv2d: 3-23                                [1, 12, 100, 100]         (recursive)
# │    │    └─Sequential: 3-24                            [1, 256, 50, 50]          (recursive)
# │    │    └─Conv2d: 3-25                                [1, 3, 50, 50]            (recursive)
# │    │    └─Conv2d: 3-26                                [1, 12, 50, 50]           (recursive)
# │    │    └─Sequential: 3-27                            [1, 256, 25, 25]          (recursive)
# │    │    └─Conv2d: 3-28                                [1, 3, 25, 25]            (recursive)
# │    │    └─Conv2d: 3-29                                [1, 12, 25, 25]           (recursive)
# │    │    └─Sequential: 3-30                            [1, 256, 13, 13]          (recursive)
# │    │    └─Conv2d: 3-31                                [1, 3, 13, 13]            (recursive)
# │    │    └─Conv2d: 3-32                                [1, 12, 13, 13]           (recursive)
# │    └─AnchorGenerator: 2-4                             [159882, 4]               --
# ├─RoIHeads: 1-4                                         [100, 4]                  --
# │    └─MultiScaleRoIAlign: 2-5                          [1000, 256, 7, 7]         --
# │    └─TwoMLPHead: 2-6                                  [1000, 1024]              --
# │    │    └─Linear: 3-33                                [1000, 1024]              12,846,080
# │    │    └─Linear: 3-34                                [1000, 1024]              1,049,600
# │    └─FastRCNNPredictor: 2-7                           [1000, 4]                 --
# │    │    └─Linear: 3-35                                [1000, 4]                 4,100
# │    │    └─Linear: 3-36                                [1000, 16]                16,400
# =========================================================================================================
# Total params: 41,309,411
# Trainable params: 41,087,011
# Non-trainable params: 222,400
# Total mult-adds (G): 133.98
# =========================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 1483.77
# Params size (MB): 165.24
# Estimated Total Size (MB): 1649.61
# =========================================================================================================

# %%
def train_batch(batch, model, optim):
    model.train()
    imgs, targets = batch
    imgs = list(img.to(device) for img in imgs)
    targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
    optim.zero_grad()
    losses = model(imgs, targets)
    loss = sum(loss for loss in losses.values())
    loss.backward()
    optim.step()
    return loss, losses

@torch.no_grad()
def validate_batch(batch, model, optim):
    model.train()
    imgs, targets = batch
    imgs = list(img.to(device) for img in imgs)
    targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
    optim.zero_grad()
    losses = model(imgs, targets)
    loss = sum(loss for loss in losses.values())
    return loss, losses

model = get_model().to(device)
optim = torch.optim.SGD(model.parameters(), lr=0.005,
                       weight_decay=5e-4, momentum=0.9)

n_epochs = 2
log = Report(n_epochs)
for e in range(n_epochs):
    for i, batch in enumerate(train_dl):
        N = len(train_dl)
        loss, losses = train_batch(batch, model, optim)
        loc_loss, regr_loss, loss_objectness, loss_rpn_box_reg = [losses[k] for k in
                                                                  ['loss_classifier', 'loss_box_reg', 'loss_objectness', 'loss_rpn_box_reg']]
        log.record(e + (i+1)/N, trn_loss=loss.item(), trn_loc_loss=loc_loss.item(),
                   trn_regr_loss=regr_loss.item(), trn_loss_objectness=loss_objectness.item(),
                   trn_loss_rpn_box_reg = loss_rpn_box_reg.item())
    for i, batch in enumerate(val_dl):
        N = len(val_dl)
        loss, losses = validate_batch(batch, model.float(), optim)
        loc_loss, regr_loss, loss_objectness, loss_rpn_box_reg = [losses[k] for k in
                                                                  ['loss_classifier', 'loss_box_reg',
                                                                   'loss_objectness', 'loss_rpn_box_reg']]
        log.record(e + (i+1)/N, val_loss=loss.item(), val_loc_loss=loc_loss.item(),
                   val_regr_loss=regr_loss.item(), val_loss_objectness=loss_objectness.item(),
                   val_loss_rpn_box_reg = loss_rpn_box_reg.item())
    log.report_avgs(e+1)
log.plot_epochs(['trn_loss', 'val_loss'])
# Out:
# EPOCH: 0.067  trn_loss: 1.932  trn_loc_loss: 1.522  trn_regr_loss: 0.402  trn_loss_objectness: 0.006  trn_loss_rpn_box_reg: 0.002  (1.46s - 42.35s remaining)
# EPOCH: 0.133  trn_loss: 0.949  trn_loc_loss: 0.522  trn_regr_loss: 0.404  trn_loss_objectness: 0.013  trn_loss_rpn_box_reg: 0.010  (2.22s - 31.03s remaining)
# EPOCH: 0.200  trn_loss: 0.309  trn_loc_loss: 0.159  trn_regr_loss: 0.138  trn_loss_objectness: 0.005  trn_loss_rpn_box_reg: 0.006  (3.07s - 27.62s remaining)
# EPOCH: 0.267  trn_loss: 0.546  trn_loc_loss: 0.294  trn_regr_loss: 0.245  trn_loss_objectness: 0.002  trn_loss_rpn_box_reg: 0.006  (3.83s - 24.92s remaining)
# EPOCH: 0.333  trn_loss: 0.839  trn_loc_loss: 0.523  trn_regr_loss: 0.304  trn_loss_objectness: 0.006  trn_loss_rpn_box_reg: 0.007  (4.55s - 22.77s remaining)
# EPOCH: 0.400  trn_loss: 0.732  trn_loc_loss: 0.441  trn_regr_loss: 0.285  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.003  (5.26s - 21.05s remaining)
# EPOCH: 0.467  trn_loss: 0.356  trn_loc_loss: 0.199  trn_regr_loss: 0.141  trn_loss_objectness: 0.011  trn_loss_rpn_box_reg: 0.005  (6.02s - 19.78s remaining)
# EPOCH: 0.533  trn_loss: 1.255  trn_loc_loss: 0.614  trn_regr_loss: 0.610  trn_loss_objectness: 0.017  trn_loss_rpn_box_reg: 0.014  (6.90s - 18.96s remaining)
# EPOCH: 0.600  trn_loss: 0.530  trn_loc_loss: 0.247  trn_regr_loss: 0.279  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.002  (7.62s - 17.78s remaining)
# EPOCH: 0.667  trn_loss: 0.416  trn_loc_loss: 0.171  trn_regr_loss: 0.232  trn_loss_objectness: 0.005  trn_loss_rpn_box_reg: 0.008  (8.33s - 16.67s remaining)
# EPOCH: 0.733  trn_loss: 0.388  trn_loc_loss: 0.146  trn_regr_loss: 0.228  trn_loss_objectness: 0.008  trn_loss_rpn_box_reg: 0.006  (9.07s - 15.66s remaining)
# EPOCH: 0.800  trn_loss: 0.238  trn_loc_loss: 0.095  trn_regr_loss: 0.127  trn_loss_objectness: 0.013  trn_loss_rpn_box_reg: 0.003  (9.78s - 14.67s remaining)
# EPOCH: 0.867  trn_loss: 0.247  trn_loc_loss: 0.099  trn_regr_loss: 0.117  trn_loss_objectness: 0.009  trn_loss_rpn_box_reg: 0.022  (10.53s - 13.77s remaining)
# EPOCH: 0.933  trn_loss: 0.365  trn_loc_loss: 0.154  trn_regr_loss: 0.181  trn_loss_objectness: 0.021  trn_loss_rpn_box_reg: 0.009  (11.27s - 12.88s remaining)
# EPOCH: 1.000  trn_loss: 0.499  trn_loc_loss: 0.197  trn_regr_loss: 0.284  trn_loss_objectness: 0.012  trn_loss_rpn_box_reg: 0.006  (12.03s - 12.03s remaining)
# EPOCH: 0.033  val_loss: 0.455  val_loc_loss: 0.163  val_regr_loss: 0.277  val_loss_objectness: 0.008  val_loss_rpn_box_reg: 0.006  (12.26s - 723.52s remaining)
# EPOCH: 0.067  val_loss: 0.212  val_loc_loss: 0.081  val_regr_loss: 0.106  val_loss_objectness: 0.004  val_loss_rpn_box_reg: 0.021  (12.43s - 360.42s remaining)
# EPOCH: 0.100  val_loss: 0.215  val_loc_loss: 0.089  val_regr_loss: 0.120  val_loss_objectness: 0.002  val_loss_rpn_box_reg: 0.004  (12.59s - 239.30s remaining)
# EPOCH: 0.133  val_loss: 0.284  val_loc_loss: 0.108  val_regr_loss: 0.167  val_loss_objectness: 0.006  val_loss_rpn_box_reg: 0.003  (12.76s - 178.60s remaining)
# EPOCH: 0.167  val_loss: 0.520  val_loc_loss: 0.188  val_regr_loss: 0.312  val_loss_objectness: 0.014  val_loss_rpn_box_reg: 0.005  (12.94s - 142.31s remaining)
# EPOCH: 0.200  val_loss: 0.612  val_loc_loss: 0.192  val_regr_loss: 0.397  val_loss_objectness: 0.011  val_loss_rpn_box_reg: 0.012  (13.14s - 118.23s remaining)
# EPOCH: 0.233  val_loss: 0.396  val_loc_loss: 0.156  val_regr_loss: 0.224  val_loss_objectness: 0.011  val_loss_rpn_box_reg: 0.005  (13.33s - 100.92s remaining)
# EPOCH: 0.267  val_loss: 0.214  val_loc_loss: 0.069  val_regr_loss: 0.115  val_loss_objectness: 0.014  val_loss_rpn_box_reg: 0.016  (13.53s - 87.93s remaining)
# EPOCH: 0.300  val_loss: 0.617  val_loc_loss: 0.228  val_regr_loss: 0.354  val_loss_objectness: 0.014  val_loss_rpn_box_reg: 0.021  (13.73s - 77.80s remaining)
# EPOCH: 0.333  val_loss: 0.252  val_loc_loss: 0.099  val_regr_loss: 0.140  val_loss_objectness: 0.011  val_loss_rpn_box_reg: 0.002  (13.97s - 69.84s remaining)
# EPOCH: 0.367  val_loss: 0.466  val_loc_loss: 0.165  val_regr_loss: 0.290  val_loss_objectness: 0.007  val_loss_rpn_box_reg: 0.005  (14.15s - 63.01s remaining)
# EPOCH: 0.400  val_loss: 0.210  val_loc_loss: 0.095  val_regr_loss: 0.106  val_loss_objectness: 0.004  val_loss_rpn_box_reg: 0.006  (14.34s - 57.34s remaining)
# EPOCH: 0.433  val_loss: 0.529  val_loc_loss: 0.209  val_regr_loss: 0.304  val_loss_objectness: 0.005  val_loss_rpn_box_reg: 0.011  (14.55s - 52.62s remaining)
# EPOCH: 0.467  val_loss: 0.506  val_loc_loss: 0.200  val_regr_loss: 0.284  val_loss_objectness: 0.009  val_loss_rpn_box_reg: 0.014  (14.75s - 48.45s remaining)
# EPOCH: 0.500  val_loss: 0.333  val_loc_loss: 0.113  val_regr_loss: 0.216  val_loss_objectness: 0.000  val_loss_rpn_box_reg: 0.003  (14.93s - 44.79s remaining)
# EPOCH: 0.533  val_loss: 0.190  val_loc_loss: 0.067  val_regr_loss: 0.117  val_loss_objectness: 0.004  val_loss_rpn_box_reg: 0.002  (15.13s - 41.61s remaining)
# EPOCH: 0.567  val_loss: 1.108  val_loc_loss: 0.370  val_regr_loss: 0.722  val_loss_objectness: 0.004  val_loss_rpn_box_reg: 0.011  (15.31s - 38.72s remaining)
# EPOCH: 0.600  val_loss: 0.654  val_loc_loss: 0.270  val_regr_loss: 0.350  val_loss_objectness: 0.024  val_loss_rpn_box_reg: 0.010  (15.49s - 36.14s remaining)
# EPOCH: 0.633  val_loss: 0.699  val_loc_loss: 0.283  val_regr_loss: 0.408  val_loss_objectness: 0.006  val_loss_rpn_box_reg: 0.002  (15.68s - 33.85s remaining)
# EPOCH: 0.667  val_loss: 0.314  val_loc_loss: 0.100  val_regr_loss: 0.204  val_loss_objectness: 0.007  val_loss_rpn_box_reg: 0.003  (15.86s - 31.72s remaining)
# EPOCH: 0.700  val_loss: 0.176  val_loc_loss: 0.072  val_regr_loss: 0.098  val_loss_objectness: 0.004  val_loss_rpn_box_reg: 0.002  (16.04s - 29.79s remaining)
# EPOCH: 0.733  val_loss: 0.690  val_loc_loss: 0.247  val_regr_loss: 0.409  val_loss_objectness: 0.017  val_loss_rpn_box_reg: 0.017  (16.25s - 28.07s remaining)
# EPOCH: 0.767  val_loss: 0.338  val_loc_loss: 0.140  val_regr_loss: 0.190  val_loss_objectness: 0.006  val_loss_rpn_box_reg: 0.002  (16.42s - 26.42s remaining)
# EPOCH: 0.800  val_loss: 0.578  val_loc_loss: 0.191  val_regr_loss: 0.378  val_loss_objectness: 0.006  val_loss_rpn_box_reg: 0.003  (16.60s - 24.90s remaining)
# EPOCH: 0.833  val_loss: 0.465  val_loc_loss: 0.164  val_regr_loss: 0.266  val_loss_objectness: 0.012  val_loss_rpn_box_reg: 0.024  (16.78s - 23.50s remaining)
# EPOCH: 0.867  val_loss: 0.219  val_loc_loss: 0.081  val_regr_loss: 0.120  val_loss_objectness: 0.012  val_loss_rpn_box_reg: 0.005  (16.98s - 22.21s remaining)
# EPOCH: 0.900  val_loss: 0.241  val_loc_loss: 0.079  val_regr_loss: 0.154  val_loss_objectness: 0.006  val_loss_rpn_box_reg: 0.002  (17.18s - 21.00s remaining)
# EPOCH: 0.933  val_loss: 0.582  val_loc_loss: 0.219  val_regr_loss: 0.338  val_loss_objectness: 0.013  val_loss_rpn_box_reg: 0.013  (17.36s - 19.84s remaining)
# EPOCH: 0.967  val_loss: 0.454  val_loc_loss: 0.148  val_regr_loss: 0.263  val_loss_objectness: 0.022  val_loss_rpn_box_reg: 0.021  (17.51s - 18.72s remaining)
# EPOCH: 1.000  val_loss: 0.232  val_loc_loss: 0.092  val_regr_loss: 0.136  val_loss_objectness: 0.004  val_loss_rpn_box_reg: 0.001  (17.68s - 17.68s remaining)
# EPOCH: 1.000  val_loss_rpn_box_reg: 0.009  trn_loss: 0.650  trn_loc_loss: 0.370  val_regr_loss: 0.256  val_loss_objectness: 0.009  trn_regr_loss: 0.264  trn_loss_objectness: 0.009  trn_loss_rpn_box_reg: 0.007  val_loc_loss: 0.158  val_loss: 0.432  (17.68s - 17.68s remaining)
# EPOCH: 1.067  trn_loss: 0.221  trn_loc_loss: 0.085  trn_regr_loss: 0.130  trn_loss_objectness: 0.004  trn_loss_rpn_box_reg: 0.003  (18.41s - 16.11s remaining)
# EPOCH: 1.133  trn_loss: 0.371  trn_loc_loss: 0.130  trn_regr_loss: 0.217  trn_loss_objectness: 0.011  trn_loss_rpn_box_reg: 0.012  (19.13s - 14.63s remaining)
# EPOCH: 1.200  trn_loss: 0.322  trn_loc_loss: 0.111  trn_regr_loss: 0.190  trn_loss_objectness: 0.008  trn_loss_rpn_box_reg: 0.013  (19.85s - 13.23s remaining)
# EPOCH: 1.267  trn_loss: 0.232  trn_loc_loss: 0.083  trn_regr_loss: 0.135  trn_loss_objectness: 0.007  trn_loss_rpn_box_reg: 0.007  (20.58s - 11.92s remaining)
# EPOCH: 1.333  trn_loss: 0.427  trn_loc_loss: 0.184  trn_regr_loss: 0.225  trn_loss_objectness: 0.008  trn_loss_rpn_box_reg: 0.010  (21.33s - 10.67s remaining)
# EPOCH: 1.400  trn_loss: 0.607  trn_loc_loss: 0.222  trn_regr_loss: 0.364  trn_loss_objectness: 0.011  trn_loss_rpn_box_reg: 0.009  (22.07s - 9.46s remaining)
# EPOCH: 1.467  trn_loss: 0.478  trn_loc_loss: 0.173  trn_regr_loss: 0.280  trn_loss_objectness: 0.017  trn_loss_rpn_box_reg: 0.009  (22.83s - 8.30s remaining)
# EPOCH: 1.533  trn_loss: 0.564  trn_loc_loss: 0.204  trn_regr_loss: 0.346  trn_loss_objectness: 0.010  trn_loss_rpn_box_reg: 0.004  (23.58s - 7.18s remaining)
# EPOCH: 1.600  trn_loss: 0.335  trn_loc_loss: 0.117  trn_regr_loss: 0.207  trn_loss_objectness: 0.004  trn_loss_rpn_box_reg: 0.008  (24.31s - 6.08s remaining)
# EPOCH: 1.667  trn_loss: 0.280  trn_loc_loss: 0.099  trn_regr_loss: 0.174  trn_loss_objectness: 0.003  trn_loss_rpn_box_reg: 0.003  (25.08s - 5.02s remaining)
# EPOCH: 1.733  trn_loss: 0.362  trn_loc_loss: 0.130  trn_regr_loss: 0.218  trn_loss_objectness: 0.008  trn_loss_rpn_box_reg: 0.006  (25.83s - 3.97s remaining)
# EPOCH: 1.800  trn_loss: 0.393  trn_loc_loss: 0.138  trn_regr_loss: 0.245  trn_loss_objectness: 0.005  trn_loss_rpn_box_reg: 0.006  (26.56s - 2.95s remaining)
# EPOCH: 1.867  trn_loss: 0.420  trn_loc_loss: 0.135  trn_regr_loss: 0.271  trn_loss_objectness: 0.007  trn_loss_rpn_box_reg: 0.007  (27.32s - 1.95s remaining)
# EPOCH: 1.933  trn_loss: 0.602  trn_loc_loss: 0.241  trn_regr_loss: 0.345  trn_loss_objectness: 0.007  trn_loss_rpn_box_reg: 0.009  (28.08s - 0.97s remaining)
# EPOCH: 2.000  trn_loss: 0.455  trn_loc_loss: 0.155  trn_regr_loss: 0.283  trn_loss_objectness: 0.012  trn_loss_rpn_box_reg: 0.006  (28.85s - 0.00s remaining)
# EPOCH: 1.033  val_loss: 0.441  val_loc_loss: 0.153  val_regr_loss: 0.284  val_loss_objectness: 0.000  val_loss_rpn_box_reg: 0.004  (29.04s - 27.16s remaining)
# EPOCH: 1.067  val_loss: 0.334  val_loc_loss: 0.093  val_regr_loss: 0.234  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.007  (29.23s - 25.57s remaining)
# EPOCH: 1.100  val_loss: 0.468  val_loc_loss: 0.160  val_regr_loss: 0.302  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.005  (29.46s - 24.10s remaining)
# EPOCH: 1.133  val_loss: 0.632  val_loc_loss: 0.237  val_regr_loss: 0.382  val_loss_objectness: 0.002  val_loss_rpn_box_reg: 0.011  (29.65s - 22.68s remaining)
# EPOCH: 1.167  val_loss: 0.384  val_loc_loss: 0.110  val_regr_loss: 0.261  val_loss_objectness: 0.005  val_loss_rpn_box_reg: 0.008  (29.84s - 21.32s remaining)
# EPOCH: 1.200  val_loss: 0.483  val_loc_loss: 0.202  val_regr_loss: 0.265  val_loss_objectness: 0.005  val_loss_rpn_box_reg: 0.012  (30.03s - 20.02s remaining)
# EPOCH: 1.233  val_loss: 0.431  val_loc_loss: 0.170  val_regr_loss: 0.241  val_loss_objectness: 0.013  val_loss_rpn_box_reg: 0.007  (30.20s - 18.77s remaining)
# EPOCH: 1.267  val_loss: 0.469  val_loc_loss: 0.151  val_regr_loss: 0.303  val_loss_objectness: 0.011  val_loss_rpn_box_reg: 0.004  (30.38s - 17.59s remaining)
# EPOCH: 1.300  val_loss: 0.214  val_loc_loss: 0.087  val_regr_loss: 0.118  val_loss_objectness: 0.006  val_loss_rpn_box_reg: 0.002  (30.56s - 16.45s remaining)
# EPOCH: 1.333  val_loss: 0.231  val_loc_loss: 0.070  val_regr_loss: 0.144  val_loss_objectness: 0.004  val_loss_rpn_box_reg: 0.013  (30.72s - 15.36s remaining)
# EPOCH: 1.367  val_loss: 0.348  val_loc_loss: 0.108  val_regr_loss: 0.237  val_loss_objectness: 0.000  val_loss_rpn_box_reg: 0.003  (30.89s - 14.32s remaining)
# EPOCH: 1.400  val_loss: 0.319  val_loc_loss: 0.106  val_regr_loss: 0.178  val_loss_objectness: 0.024  val_loss_rpn_box_reg: 0.010  (31.06s - 13.31s remaining)
# EPOCH: 1.433  val_loss: 0.297  val_loc_loss: 0.104  val_regr_loss: 0.187  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.005  (31.23s - 12.35s remaining)
# EPOCH: 1.467  val_loss: 0.161  val_loc_loss: 0.053  val_regr_loss: 0.094  val_loss_objectness: 0.002  val_loss_rpn_box_reg: 0.012  (31.39s - 11.42s remaining)
# EPOCH: 1.500  val_loss: 0.134  val_loc_loss: 0.047  val_regr_loss: 0.081  val_loss_objectness: 0.002  val_loss_rpn_box_reg: 0.005  (31.57s - 10.52s remaining)
# EPOCH: 1.533  val_loss: 0.181  val_loc_loss: 0.057  val_regr_loss: 0.115  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.008  (31.74s - 9.66s remaining)
# EPOCH: 1.567  val_loss: 0.553  val_loc_loss: 0.190  val_regr_loss: 0.348  val_loss_objectness: 0.007  val_loss_rpn_box_reg: 0.008  (31.90s - 8.82s remaining)
# EPOCH: 1.600  val_loss: 0.369  val_loc_loss: 0.118  val_regr_loss: 0.243  val_loss_objectness: 0.002  val_loss_rpn_box_reg: 0.005  (32.07s - 8.02s remaining)
# EPOCH: 1.633  val_loss: 0.255  val_loc_loss: 0.107  val_regr_loss: 0.134  val_loss_objectness: 0.010  val_loss_rpn_box_reg: 0.004  (32.25s - 7.24s remaining)
# EPOCH: 1.667  val_loss: 0.117  val_loc_loss: 0.037  val_regr_loss: 0.065  val_loss_objectness: 0.009  val_loss_rpn_box_reg: 0.006  (32.45s - 6.49s remaining)
# EPOCH: 1.700  val_loss: 0.475  val_loc_loss: 0.158  val_regr_loss: 0.311  val_loss_objectness: 0.002  val_loss_rpn_box_reg: 0.004  (32.63s - 5.76s remaining)
# EPOCH: 1.733  val_loss: 0.620  val_loc_loss: 0.215  val_regr_loss: 0.398  val_loss_objectness: 0.005  val_loss_rpn_box_reg: 0.003  (32.80s - 5.05s remaining)
# EPOCH: 1.767  val_loss: 0.536  val_loc_loss: 0.192  val_regr_loss: 0.330  val_loss_objectness: 0.007  val_loss_rpn_box_reg: 0.007  (32.96s - 4.35s remaining)
# EPOCH: 1.800  val_loss: 0.210  val_loc_loss: 0.070  val_regr_loss: 0.129  val_loss_objectness: 0.006  val_loss_rpn_box_reg: 0.005  (33.13s - 3.68s remaining)
# EPOCH: 1.833  val_loss: 0.197  val_loc_loss: 0.061  val_regr_loss: 0.120  val_loss_objectness: 0.011  val_loss_rpn_box_reg: 0.004  (33.30s - 3.03s remaining)
# EPOCH: 1.867  val_loss: 0.448  val_loc_loss: 0.153  val_regr_loss: 0.287  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.007  (33.48s - 2.39s remaining)
# EPOCH: 1.900  val_loss: 0.551  val_loc_loss: 0.206  val_regr_loss: 0.340  val_loss_objectness: 0.003  val_loss_rpn_box_reg: 0.002  (33.70s - 1.77s remaining)
# EPOCH: 1.933  val_loss: 0.503  val_loc_loss: 0.193  val_regr_loss: 0.301  val_loss_objectness: 0.006  val_loss_rpn_box_reg: 0.003  (33.87s - 1.17s remaining)
# EPOCH: 1.967  val_loss: 0.444  val_loc_loss: 0.156  val_regr_loss: 0.275  val_loss_objectness: 0.008  val_loss_rpn_box_reg: 0.006  (34.04s - 0.58s remaining)
# EPOCH: 2.000  val_loss: 0.227  val_loc_loss: 0.082  val_regr_loss: 0.140  val_loss_objectness: 0.001  val_loss_rpn_box_reg: 0.005  (34.26s - 0.00s remaining)
# EPOCH: 2.000  val_loss_rpn_box_reg: 0.006  trn_loss: 0.408  trn_loc_loss: 0.150  val_regr_loss: 0.228  val_loss_objectness: 0.005  trn_regr_loss: 0.242  trn_loss_objectness: 0.008  trn_loss_rpn_box_reg: 0.007  val_loc_loss: 0.128  val_loss: 0.368  (34.26s - 0.00s remaining)
# 100%|██████████| 103/103 [00:00<00:00, 27588.82it/s]

# %% [markdown]
# # Model Testing ⚡

# %%
from torchvision.ops import nms

def decode_output(output):
    bbs = output['boxes'].cpu().detach().numpy().astype(np.uint16)
    labels = np.array([targets2label[i] for i in output['labels'].cpu().detach().numpy()])
    confs = output['scores'].cpu().detach().numpy()
    idxs = nms(torch.tensor(bbs.astype(np.float32)), torch.tensor(confs), 0.05)
    bbs, confs, labels = [tensor[idxs] for tensor in [bbs, confs, labels]]
    if len(idxs) == 1:
        bbs, confs, labels = [np.array([tensor]) for tensor in [bbs, confs, labels]]
    return bbs.tolist(), confs.tolist(), labels.tolist()

model.eval()
for i, (images, targets) in enumerate(val_dl):
    imgs = list(img.to(device) for img in images)
    targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
    if i == 3: break
    images = [im for im in imgs]
    outputs = model(images)
    for i, output in enumerate(outputs):
        bbs, confs, labels = decode_output(output)
        plot_img_bbox(images[i].cpu().permute(1,2,0), bbs)

# %% [markdown]
# ### Segmentation

# %% [markdown]
# - Standard Model for Segmentation can be found here:
#   - https://github.com/qubvel/segmentation_models.pytorch.
#   - Walkthrough
# - YOLOv8
#   - Detection and Segmentation
#   - https://github.com/ultralytics/ultralytics
#   - Segment: https://docs.ultralytics.com/tasks/segment/
#   - Detect: https://docs.ultralytics.com/tasks/detect/

# %% [markdown]
# ## Resources worth Read:
# 1. Segmentation Survey Paper: https://ieeexplore.ieee.org/document/9356353
# 2. Detection Blog: https://viso.ai/deep-learning/object-detection/
# 3. A Comprehensive Study of Real-Time Object Detection Networks Across Multiple Domains: A Survey - https://arxiv.org/abs/2208.10895
# 4. Object Detection: https://ieeexplore.ieee.org/document/10028728
# 5. YOLO:https://www.datacamp.com/blog/yolo-object-detection-explained
# 6. Loss Functions: https://github.com/JunMa11/SegLoss
# 7. Loss Functions: https://learnopencv.com/iou-loss-functions-object-detection/

# %% [markdown]
# **Vision Foundation Model in Segmentation**:
# - SAM: Segment Anything Model
# - AI model from Meta AI that can "cut out" any object, in any image, with a single click.
# - SAM produces high-quality object masks from input prompts such as points or boxes, and it can be used to generate object masks for any image.
# - The model is designed and trained to be promptable, so it can transfer zero-shot to new image distributions and tasks.
# - SAM uses a variety of input prompts, including points or boxes, to segment objects in images.
# - The Segment Anything project also includes the Segment Anything Dataset, which is the largest ever segmentation dataset, with over 1 billion masks on 11M licensed and privacy-respecting images.
# - SAM is a starting point for foundation models for image segmentation, and it can reduce the need for task-specific modeling expertise, training compute, and custom data annotation for image segmentation.
#
# - Project: https://segment-anything.com/
